# %%
# exercise 1
dictionary_1 = {"key_1A": 1,"key_1B": 2,"key_1C": 3}
dictionary_2 = {"key_2A": 4,"key_2B": 5,"key_2C": 6}
dictionary_1.update(dictionary_2)
print (dictionary_1)
# Out:
# {'key_1A': 1, 'key_1B': 2, 'key_1C': 3, 'key_2A': 4, 'key_2B': 5, 'key_2C': 6}

# %%
# exercise 2

my_list = ["key_2","key_4","key_1","key_5","key_3"]
my_list.sort()
print (my_list) #in ascending order
my_list.sort(reverse=True)
print (my_list) #in descending order

my_set = set = set(my_list)
print (my_set) #list into set conversion
# Out:
# ['key_1', 'key_2', 'key_3', 'key_4', 'key_5']
# ['key_5', 'key_4', 'key_3', 'key_2', 'key_1']
# {'key_3', 'key_4', 'key_5', 'key_1', 'key_2'}

# %%
# exercise 3
# function to list and sort the number of items

dictionary = {"key1":3,"key2":1,"key3":2}
def alpha(my_dictionary):
    print (my_dictionary.keys())
    
alpha (dictionary)

print ("\n")

# without function

count = 0
for x in dictionary: 
    if isinstance(dictionary[x], list): 
        count += len(dictionary[x]) 
    print(x)
# Out:
# dict_keys(['key1', 'key2', 'key3'])
#
#
# key1
# key2
# key3

# %%
# exercise 4

string_1 = " one two three for five six"
print(string_1)

def search_and_replace(x):
    a=input("enter the word to search: ")
    b=input("enter the word to replace: ")
    print (x.replace(a,b,1))
    
search_and_replace(string_1)
# Out:
#  one two three for five six
# enter the word to search: for
# enter the word to replace: four
#  one two three four five six

# %%
# exercise 5

string_2 = " alpha beta gamma, alpha beta gamma, alpha beta gamma"
print (string_2)

def capitalise(y):
    c = input ("enter the world to be find: ")
    result = c.capitalize()
    print(y.replace(c,result))
    
capitalise(string_2)
# Out:
#  alpha beta gamma, alpha beta gamma, alpha beta gamma
# enter the world to be find: alpha
#  Alpha beta gamma, Alpha beta gamma, Alpha beta gamma

# %%
# exercise 6

list_1 = ["one","two","two","three","four","five","five"]

def find_repeats(z):
    ans = dict((i, z.count(i)) for i in z)
    print (ans)

find_repeats(list_1)
# Out:
# {'one': 1, 'two': 2, 'three': 1, 'four': 1, 'five': 2}

# %%
# exercise 7

print ("enter three value to be added")
l =int(input("operand_1="))
m =int(input ("operand_2="))
n =int(input ("operand_3="))
addition=l+m+n
print ("operand_1+operand_2+operand_3 =",addition)
divisor=int(input("enter the divisor="))
answer= addition/divisor
print ("your final answer is",answer)
# Out:
# enter three value to be added
# operand_1=15
# operand_2=51
# operand_3=7
# operand_1+operand_2+operand_3 = 73
# enter the divisor=8
# your final answer is 9.125

# %%
# exercise 8

num_1=int(input("operand_1="))
num_2=int(input("operand_2="))
num_3=int(input("operand_3="))
mean=(num_1+num_2+num_3)/3
print ("mean is ", mean)
median = [num_1,num_2,num_3]
median.sort()
print ("median is ",median[1])
print ("mode is ", median[2])
# Out:
# operand_1=34
# operand_2=45
# operand_3=56
# mean is  45.0
# median is  45
# mode is  56

# %%
# exercise 9

string_x="this is a demo string"
print (string_x)
print(string_x.swapcase())
# Out:
# this is a demo string
# THIS IS A DEMO STRING

# %%
# exercise 10

def DecimalToBinary(num):
    if num >= 1:
        DecimalToBinary(num // 2)
        print (num % 2)
        
DecimalToBinary(68)
# Out:
# 1
# 0
# 0
# 0
# 1
# 0
# 0
