# %%
#Exercise 1
a=10
b=10
c=10
#problem 1
print("a ÷ 10 =",a/10)
#problem 2
print("b x 50 =",b*50)
#problem 3
print("c + 60 =",c+60)
# Out:
# a ÷ 10 = 1.0
# b x 50 = 500
# c + 60 = 70

# %%
#Exercise 2
my_name = "ROHIT"
print(my_name)
my_name = my_name.replace("T","D")
print(my_name)
# Out:
# ROHIT
# ROHID

# %%
#Exercise 3
a=99
b=99.0
print ("interger form of b=",int(b ))
print ("float form of a=",float(a ))
# Out:
# interger form of b= 99
# float form of a= 99.0
